# %%
import torch

# %%
t = torch.rand(4,5)

# %%
print(t)
# Out:
# tensor([[0.8085, 0.2413, 0.9503, 0.1682, 0.0903],
#         [0.8085, 0.1849, 0.2273, 0.9474, 0.4653],
#         [0.3121, 0.7255, 0.7392, 0.9170, 0.7604],
#         [0.3451, 0.7838, 0.1670, 0.4356, 0.1761]])

# %%
labels = torch.tensor([2, 0, 4, 1])

# %%
t[0, labels]
# Out:
# tensor([0.9503, 0.8085, 0.0903, 0.2413])

# %%
t
# Out:
# tensor([[0.8085, 0.2413, 0.9503, 0.1682, 0.0903],
#         [0.8085, 0.1849, 0.2273, 0.9474, 0.4653],
#         [0.3121, 0.7255, 0.7392, 0.9170, 0.7604],
#         [0.3451, 0.7838, 0.1670, 0.4356, 0.1761]])

# %%
pythongrid = [
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90],
]

# %%
rows = [0, 1, 2]

# %%
cols = [2, 0, 1]

# %%
import torch
t = torch.tensor(pythongrid)
print(t[rows, cols])
# Out:
# tensor([30, 40, 80])
